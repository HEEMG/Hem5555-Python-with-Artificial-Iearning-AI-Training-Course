# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('https://en.setopati.com/political', 'html.parser')
url
# Out:
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://en.setopati.com/political" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# https://en.setopati.com/political

# %%
response = requests.get(url)
data = response.text
data = BeautifulSoup(data,'lxml')
data
# Out:
# <!--<header>--><!DOCTYPE html>
# <html>
# <head>
# <meta content="691077371279161" property="fb:app_id"/>
# <script>
#             (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#             })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#             ga('create', 'UA-101649819-1', 'auto');
#             ga('set', 'appName', 'Setopati Website');
#             ga('send', 'pageview');
#             ga('send', 'timing', 'JS Dependencies', 'load', 3549);
#             ga('send', 'screenview', {screenName: 'http://en.setopati.com/political' });
#             try {
#             window.possiblyUndefinedFunction();
#             } catch(err) {
#             ga('send', 'exception', {
# ...

# %%
raw_data = data.find_all("div", class_="items col-md-4")
raw_data
# Out:
# [<div class="items col-md-4">
#  <a href="https://en.setopati.com/political/155360" title="JSP meeting expected to decide about government formation called off">
#  <figure>
#  <img alt="" src="https://en.setopati.com/uploads/images/450X285/1616070084Baburam_mahantha_UpendraYadav.jpg"/>
#  <span class="tags">Politics</span>
#  </figure>
#  <span class="main-title">JSP meeting expected to decide about government formation called off</span>
#  </a>
#  <div class="date-stamp">
#  <span class="author-left"><span class="left-icon fa fa-edit"></span><span class="author-title">Prashanna Pokharel</span></span>
#  <span class="time-stamp"><span class="left-icon fa fa-clock-o"></span>Thursday, Chaitra 5, 2077</span>
#  </div>
#  </div>, <div class="items col-md-4">
#  <a href="https://en.setopati.com/political/155359" title="Maoist Center revives YCL, national convention in June">
#  <figure>
#  <img alt="" src="https://en.setopati.com/uploads/images/450X285/1616067600YCL.jpg"/>
# ...

# %%
raw_data = raw_data[0:-3]
raw_data
# Out:
# [<div class="items col-md-4">
#  <a href="https://en.setopati.com/political/155360" title="JSP meeting expected to decide about government formation called off">
#  <figure>
#  <img alt="" src="https://en.setopati.com/uploads/images/450X285/1616070084Baburam_mahantha_UpendraYadav.jpg"/>
#  <span class="tags">Politics</span>
#  </figure>
#  <span class="main-title">JSP meeting expected to decide about government formation called off</span>
#  </a>
#  <div class="date-stamp">
#  <span class="author-left"><span class="left-icon fa fa-edit"></span><span class="author-title">Prashanna Pokharel</span></span>
#  <span class="time-stamp"><span class="left-icon fa fa-clock-o"></span>Thursday, Chaitra 5, 2077</span>
#  </div>
#  </div>, <div class="items col-md-4">
#  <a href="https://en.setopati.com/political/155359" title="Maoist Center revives YCL, national convention in June">
#  <figure>
#  <img alt="" src="https://en.setopati.com/uploads/images/450X285/1616067600YCL.jpg"/>
# ...

# %%
len(raw_data)
# Out:
# 29

# %%
links = []
for i in raw_data:
  j =i.find_all('a')
  k = j[0].get('href')
  links.append(k)
print(links)
# Out:
# ['https://en.setopati.com/political/155360', 'https://en.setopati.com/political/155359', 'https://en.setopati.com/political/155358', 'https://en.setopati.com/political/155352', 'https://en.setopati.com/political/155351', 'https://en.setopati.com/political/155350', 'https://en.setopati.com/political/155345', 'https://en.setopati.com/political/155344', 'https://en.setopati.com/political/155342', 'https://en.setopati.com/political/155335', 'https://en.setopati.com/political/155334', 'https://en.setopati.com/political/155333', 'https://en.setopati.com/political/155329', 'https://en.setopati.com/political/155328', 'https://en.setopati.com/political/155325', 'https://en.setopati.com/political/155322', 'https://en.setopati.com/political/155320', 'https://en.setopati.com/political/155319', 'https://en.setopati.com/political/155314', 'https://en.setopati.com/political/155312', 'https://en.setopati.com/political/155311', 'https://en.setopati.com/political/155308', 'https://en.setopati.com/poli
# ...

# %%
from bs4 import BeautifulSoup
import requests
# for i in links:
url = BeautifulSoup('https://en.setopati.com/political/155348', 'html.parser')


response = requests.get(url)
data = response.text
data = BeautifulSoup(data,'lxml')


raw_data = data.find("div", class_="editor-box")

raw_string = raw_data.text
raw_string.replace('\n','')
# Out:
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://en.setopati.com/political/155348" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ...

# %%
from bs4 import BeautifulSoup
import requests
final_news = []
for i in links:
  url = BeautifulSoup(i, 'html.parser')
  response = requests.get(url)
  data = response.text
  data = BeautifulSoup(data,'lxml')
  raw_data = data.find("div", class_="editor-box")
  raw_string = raw_data.text
  final = raw_string.replace('\n','')
  final_news.append(final)
# Out:
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://en.setopati.com/political/155360" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://en.setopati.com/political/155359" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ...

# %%
len(final_news)
# Out:
# 29

# %%
final_news
# Out:
# ['The central executive committee meeting of Janata Samwawadi Party (JSP) that was expected to decide about formation of a new government could not even be convened on Thursday.The main opposition Nepali Congress (NC) and CPN (Maoist Center) were awaiting JSP decision to form a new government excluding Prime Minister (PM) KP Sharma Oli. Maoist leader Barsha Man Pun had even claimed that a coalition government of NC, JSP and Maoist Center will be formed after JSP\'s meeting on Thursday but the party postponed the meeting citing lack of preparations.JSP Chairman Upendra Yadav said time has yet to ripen for formation of the new government. "We will stand against regressive forces like Oli," Yadav told reporters after the meeting was called off. "We cannot tie the knot with Oli. Situation has also not yet matured. Cooperation with Oli would be betrayal of the Madhes movement."He claimed that continuation of Oli as PM would help revocation of federalism.Another JSP leader told Setopati th
# ...

# %%
final_news[1]
# Out:
# 'CPN (Maoist Center) has revived Young Communist League (YCL) which will hold national convention from June 11-13.The fourth full meeting of YCL held in Kathmandu on Wednesday and Thursday after the Supreme Court (SC) invalidated unification of UML and CPN (Maoist Center) has taken the decision to that regard.The national convention will decide about the new policy and leadership of YCL, according to YCL Secretary Pushpa Oli. Oli said gatherings will be held before the national convention at the provincial and local levels to make YCL dynamic. He added that representatives for the national convention will be elected by the provincial gatherings.YCL has also aimed to induct 200,000 new members before the national convention.'

# %%
import csv   
fields=final_news
for i in range(29):
  f = open(f'political{i}.txt', 'a')
  f.write(final_news[i])
  f.close()

# %%
from bs4 import BeautifulSoup
import requests
links = []
n = int(input("Enter page no = "))
for i in range(1,n+1):
  url = BeautifulSoup(f'https://en.setopati.com/political?page={i}', 'html.parser')


  response = requests.get(url)
  data = response.text
  data = BeautifulSoup(data,'lxml')


  raw_data = data.find_all("div", class_="items col-md-4")
  raw_data = raw_data[0:-3]

  # raw_string = raw_data.text

  
  for index in raw_data:
    j =index.find_all('a')
    k = j[0].get('href')
    links.append(k)
# Out:
# Enter page no = 2
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://en.setopati.com/political?page=1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ...

# %%
len(links)
# Out:
# 58
